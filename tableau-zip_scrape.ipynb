# %%
import pandas as pd 
from selenium import webdriver
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import zipfile
import os 
import urllib
import urllib.request

# %%
import requests, zipfile
import glob

# %%
url = 'https://s3.amazonaws.com/tripdata/index.html'

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
visit = browser.visit(url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/97.0.4692.71/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Zach\.wdm\drivers\chromedriver\win32\97.0.4692.71]

# %%
zip_files = []

    # HTML object
html = browser.html
    # Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')
    # Retrieve all elements that contain book information
links = soup.find_all('a')
    # Scrape the [Mars News Site](https://redplanetscience.com/) and collect the latest News Title and Paragraph Text. 
for a in links:
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        #Assign the text to variables that you can reference later.
    link = a["href"]
    zip_files.append(link)
print(zip_files)
# Out:
# []

# %%
downloads_dir = "downloaded/"

for file in zip_files: 
    name = file.rsplit('/', 1)[-1]

    # Combine the name and the downloads directory to get the local filename
    filename = os.path.join(downloads_dir, name)
    file1 = open(filename, "w")
    file1.write("file information")
    file1.close

    # Download the file if it does not exist
    if not os.path.exists(filename):
        urllib.request.urlretrieve(url, filename)

# %%
df_2021_1 = pd.read_csv("downloaded/csvs/202001-citibike-tripdata.csv")
df_2021_1
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                 592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                 702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...               ...                       ...                       ...
# 1240591          1587  2020-01-31 23:59:26.8820  2020-02-01 00:25:54.4890
# 1240592           222  2020-01-31 23:59:32.6410  2020-02-01 00:03:15.4720
# 1240593           163  2020-01-31 23:59:39.1780  2020-02-01 00:02:23.0400
# 1240594           327  2020-01-31 23:59:49.2310  2020-02-01 00:05:16.3790
# 1240595           484  2020-01-31 23:59:57.0360  2020-02-01 00:08:01.1820
#
#          start station id               start station name  \
# ...

# %%
df_2021_2 = pd.read_csv("downloaded/csvs/202002-citibike-tripdata.csv")
df_2021_2
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1404  2020-02-01 00:00:05.9460  2020-02-01 00:23:30.7240
# 1                1301  2020-02-01 00:00:06.2230  2020-02-01 00:21:48.0580
# 2                 474  2020-02-01 00:00:15.7210  2020-02-01 00:08:10.3440
# 3                 487  2020-02-01 00:00:21.0520  2020-02-01 00:08:28.7520
# 4                 619  2020-02-01 00:00:27.4000  2020-02-01 00:10:47.0640
# ...               ...                       ...                       ...
# 1146825           203  2020-02-29 23:58:48.0230  2020-03-01 00:02:11.6640
# 1146826           357  2020-02-29 23:58:52.5640  2020-03-01 00:04:50.5370
# 1146827           169  2020-02-29 23:58:54.5820  2020-03-01 00:01:43.7770
# 1146828           738  2020-02-29 23:58:58.8110  2020-03-01 00:11:17.7390
# 1146829           960  2020-02-29 23:59:35.6070  2020-03-01 00:15:35.6490
#
#          start station id       start station name  start station latitude  \
# ...

# %%
df_2021_3 = pd.read_csv("downloaded/csvs/202003-citibike-tripdata.csv")
df_2021_3
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1589  2020-03-01 00:00:03.6400  2020-03-01 00:26:32.9860
# 1                 389  2020-03-01 00:00:16.7560  2020-03-01 00:06:46.0620
# 2                 614  2020-03-01 00:00:20.0580  2020-03-01 00:10:34.2200
# 3                 597  2020-03-01 00:00:24.3510  2020-03-01 00:10:22.3390
# 4                1920  2020-03-01 00:00:26.1120  2020-03-01 00:32:26.2680
# ...               ...                       ...                       ...
# 1068452           137  2020-03-31 23:56:06.0490  2020-03-31 23:58:23.3880
# 1068453          1548  2020-03-31 23:57:27.6850  2020-04-01 00:23:16.4110
# 1068454           308  2020-03-31 23:58:00.2690  2020-04-01 00:03:08.9500
# 1068455           872  2020-03-31 23:58:42.9010  2020-04-01 00:13:15.5860
# 1068456           306  2020-03-31 23:59:17.2580  2020-04-01 00:04:23.8880
#
#          start station id        start station name  start station latitude  \
# ...

# %%
df_2021_4 = pd.read_csv("downloaded/csvs/202004-citibike-tripdata.csv")
df_2021_4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           534  2020-04-01 00:00:15.2800  2020-04-01 00:09:09.8730
# 1           529  2020-04-01 00:02:28.9430  2020-04-01 00:11:18.3410
# 2          1488  2020-04-01 00:02:56.0900  2020-04-01 00:27:44.2530
# 3           341  2020-04-01 00:03:25.1410  2020-04-01 00:09:06.3190
# 4          2206  2020-04-01 00:05:35.2790  2020-04-01 00:42:21.9080
#
#    start station id           start station name  start station latitude  \
# 0              3656            E 2 St & Avenue A               40.723077
# 1              3163  Central Park West & W 68 St               40.773407
# 2              3164       Columbus Ave & W 72 St               40.777057
# 3              3827         Halsey St & Broadway               40.685650
# 4              3890          Grove St & Broadway               40.690470
#
#    start station longitude  end station id           end station name  \
# ...

# %%
df_2021_5 = pd.read_csv("downloaded/csvs/202005-citibike-tripdata.csv")
df_2021_5.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           336  2020-05-01 00:01:06.3380  2020-05-01 00:06:42.9560
# 1           853  2020-05-01 00:01:08.1950  2020-05-01 00:15:21.2150
# 2            78  2020-05-01 00:01:08.5260  2020-05-01 00:02:27.0490
# 3          1185  2020-05-01 00:02:22.4380  2020-05-01 00:22:08.1220
# 4           272  2020-05-01 00:02:32.8280  2020-05-01 00:07:05.0880
#
#    start station id                  start station name  \
# 0              2017                     E 43 St & 2 Ave
# 1              3376                     E 65 St & 2 Ave
# 2               396          Lefferts Pl & Franklin Ave
# 3              3630  Frederick Douglass Blvd & W 115 St
# 4              3776          Central Ave & Starr Street
#
#    start station latitude  start station longitude  end station id  \
# 0               40.750224               -73.971214             465
# 1               40.764719               -73.962221             478
# ...

# %%
df_2021_6 = pd.read_csv("downloaded/csvs/202006-citibike-tripdata.csv")
df_2021_6.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1062  2020-06-01 00:00:03.3720  2020-06-01 00:17:46.2080
# 1          3810  2020-06-01 00:00:03.5530  2020-06-01 01:03:33.9360
# 2          1017  2020-06-01 00:00:09.6140  2020-06-01 00:17:06.8330
# 3           226  2020-06-01 00:00:12.1780  2020-06-01 00:03:58.8640
# 4          1437  2020-06-01 00:00:21.2550  2020-06-01 00:24:18.9650
#
#    start station id        start station name  start station latitude  \
# 0              3419       Douglass St & 4 Ave               40.679279
# 1               366  Clinton Ave & Myrtle Ave               40.693261
# 2               389       Broadway & Berry St               40.710446
# 3              3255           8 Ave & W 31 St               40.750585
# 4               367   E 53 St & Lexington Ave               40.758281
#
#    start station longitude  end station id             end station name  \
# ...

# %%
df_2021_7 = pd.read_csv("downloaded/csvs/202007-citibike-tripdata.csv")
df_2021_7.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           341  2020-07-01 00:00:01.3020  2020-07-01 00:05:42.5650
# 1           321  2020-07-01 00:00:01.3620  2020-07-01 00:05:22.9490
# 2          2710  2020-07-01 00:00:06.6290  2020-07-01 00:45:17.3410
# 3          2685  2020-07-01 00:00:13.0220  2020-07-01 00:44:58.8640
# 4           191  2020-07-01 00:00:13.4660  2020-07-01 00:03:24.6230
#
#    start station id     start station name  start station latitude  \
# 0              3463    E 16 St & Irving Pl               40.735367
# 1              3463    E 16 St & Irving Pl               40.735367
# 2               426  West St & Chambers St               40.717548
# 3               426  West St & Chambers St               40.717548
# 4              3615          44 Dr & 21 St               40.748000
#
#    start station longitude  end station id         end station name  \
# 0               -73.987974            2003          1 Ave & E 18 St
# ...

# %%
df_2021_8 = pd.read_csv("downloaded/csvs/202008-citibike-tripdata.csv")
df_2021_8.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2013  2020-08-01 00:00:00.8790  2020-08-01 00:33:34.7260
# 1          7002  2020-08-01 00:00:01.5910  2020-08-01 01:56:44.0720
# 2           155  2020-08-01 00:00:03.5810  2020-08-01 00:02:38.6340
# 3          2720  2020-08-01 00:00:05.0130  2020-08-01 00:45:25.3270
# 4          2938  2020-08-01 00:00:05.9420  2020-08-01 00:49:03.9640
#
#    start station id                   start station name  \
# 0              3295             Central Park W & W 96 St
# 1              3144                   E 81 St & Park Ave
# 2               387              Centre St & Chambers St
# 3              3080                   S 4 St & Rodney St
# 4              3510  Adam Clayton Powell Blvd & W 123 St
#
#    start station latitude  start station longitude  end station id  \
# 0               40.791270               -73.964839            3992
# 1               40.776777               -73.959010            3671
# ...

# %%
df_2021_9 = pd.read_csv("downloaded/csvs/202009-citibike-tripdata.csv")
df_2021_9.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          4225  2020-09-01 00:00:01.0430  2020-09-01 01:10:26.6350
# 1          1868  2020-09-01 00:00:04.8320  2020-09-01 00:31:13.7650
# 2          1097  2020-09-01 00:00:06.8990  2020-09-01 00:18:24.2260
# 3          1473  2020-09-01 00:00:07.7440  2020-09-01 00:24:41.1800
# 4          1193  2020-09-01 00:00:12.2020  2020-09-01 00:20:05.5470
#
#    start station id               start station name  start station latitude  \
# 0              3508  St Nicholas Ave & Manhattan Ave               40.809725
# 1              3621                    27 Ave & 9 St               40.773983
# 2              3492              E 118 St & Park Ave               40.800539
# 3              3946       St Nicholas Ave & W 137 St               40.818477
# 4              3081            Graham Ave & Grand St               40.711863
#
#    start station longitude  end station id  \
# 0               -73.953149             116
# ...

# %%
df_2021_10 = pd.read_csv("downloaded/csvs/202010-citibike-tripdata.csv")
df_2021_10.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1403  2020-10-01 00:00:10.7870  2020-10-01 00:23:34.5400
# 1           462  2020-10-01 00:00:18.2390  2020-10-01 00:08:00.5710
# 2           770  2020-10-01 00:00:21.3070  2020-10-01 00:13:12.0840
# 3           233  2020-10-01 00:00:25.0080  2020-10-01 00:04:18.6410
# 4           126  2020-10-01 00:00:25.3100  2020-10-01 00:02:32.1330
#
#    start station id        start station name  start station latitude  \
# 0               224     Spruce St & Nassau St               40.711464
# 1              3161    W 76 St & Columbus Ave               40.780184
# 2               354   Emerson Pl & Myrtle Ave               40.693631
# 3              3141           1 Ave & E 68 St               40.765005
# 4               335  Washington Pl & Broadway               40.729039
#
#    start station longitude  end station id           end station name  \
# ...

# %%
df_2021_11 = pd.read_csv("downloaded/csvs/202011-citibike-tripdata.csv")
df_2021_11.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           521  2020-11-01 00:00:07.0150  2020-11-01 00:08:48.3010
# 1           492  2020-11-01 00:00:10.8080  2020-11-01 00:08:23.3170
# 2          1979  2020-11-01 00:00:14.7040  2020-11-01 00:33:14.1640
# 3          2382  2020-11-01 00:00:14.7070  2020-11-01 00:39:57.0030
# 4           166  2020-11-01 00:00:15.9690  2020-11-01 00:03:02.8980
#
#    start station id      start station name  start station latitude  \
# 0              3467  W Broadway & Spring St               40.724947
# 1              3557           40 Ave & 9 St               40.757420
# 2              3085    Roebling St & N 4 St               40.714690
# 3              3783    Cliff St & Fulton St               40.708380
# 4               422        W 59 St & 10 Ave               40.770513
#
#    start station longitude  end station id          end station name  \
# 0               -74.001659             350     Clinton St & Grand St
# ...

# %%
df_2021_12 = pd.read_csv("downloaded/csvs/202012-citibike-tripdata.csv")
df_2021_12.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           694  2020-12-01 00:00:03.7770  2020-12-01 00:11:38.3160
# 1          4131  2020-12-01 00:00:09.1730  2020-12-01 01:09:00.2370
# 2          1368  2020-12-01 00:00:28.7470  2020-12-01 00:23:16.9980
# 3          1707  2020-12-01 00:00:34.7680  2020-12-01 00:29:02.6470
# 4          2182  2020-12-01 00:00:36.4030  2020-12-01 00:36:59.0330
#
#    start station id           start station name  start station latitude  \
# 0              4065     Wadsworth Ave & W 179 St               40.848467
# 1              3284           E 88 St & Park Ave               40.781411
# 2              3443              W 52 St & 6 Ave               40.761330
# 3                72             W 52 St & 11 Ave               40.767272
# 4              3165  Central Park West & W 72 St               40.775794
#
#    start station longitude  end station id          end station name  \
# ...

# %%
combined_2020_df = pd.merge(df_2021_1, df_2021_2, how="outer")
combined_2020_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                 592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                 702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...               ...                       ...                       ...
# 2387421           203  2020-02-29 23:58:48.0230  2020-03-01 00:02:11.6640
# 2387422           357  2020-02-29 23:58:52.5640  2020-03-01 00:04:50.5370
# 2387423           169  2020-02-29 23:58:54.5820  2020-03-01 00:01:43.7770
# 2387424           738  2020-02-29 23:58:58.8110  2020-03-01 00:11:17.7390
# 2387425           960  2020-02-29 23:59:35.6070  2020-03-01 00:15:35.6490
#
#          start station id               start station name  \
# ...

# %%
combined_2020_df = pd.merge(combined_2020_df, df_2021_3, how="outer")
combined_2020_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                 592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                 702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...               ...                       ...                       ...
# 3455878           137  2020-03-31 23:56:06.0490  2020-03-31 23:58:23.3880
# 3455879          1548  2020-03-31 23:57:27.6850  2020-04-01 00:23:16.4110
# 3455880           308  2020-03-31 23:58:00.2690  2020-04-01 00:03:08.9500
# 3455881           872  2020-03-31 23:58:42.9010  2020-04-01 00:13:15.5860
# 3455882           306  2020-03-31 23:59:17.2580  2020-04-01 00:04:23.8880
#
#          start station id               start station name  \
# ...

# %%
combined_2020_df = pd.merge(combined_2020_df, df_2021_4, how="outer")
combined_2020_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                 592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                 702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...               ...                       ...                       ...
# 4138640          1680  2020-04-30 23:59:00.7780  2020-05-01 00:27:01.7600
# 4138641          1334  2020-04-30 23:59:23.6460  2020-05-01 00:21:38.2190
# 4138642          1334  2020-04-30 23:59:33.6760  2020-05-01 00:21:48.2150
# 4138643           234  2020-04-30 23:59:56.9720  2020-05-01 00:03:51.9600
# 4138644           267  2020-04-30 23:59:59.3510  2020-05-01 00:04:26.8110
#
#          start station id               start station name  \
# ...

# %%
combined_2020_df = pd.merge(combined_2020_df, df_2021_5, how="outer")
combined_2020_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                 592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                 702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...               ...                       ...                       ...
# 5626530           981  2020-05-31 23:59:19.0310  2020-06-01 00:15:40.5590
# 5626531           367  2020-05-31 23:59:36.2270  2020-06-01 00:05:43.6200
# 5626532          1798  2020-05-31 23:59:37.7250  2020-06-01 00:29:36.6800
# 5626533           718  2020-05-31 23:59:47.7090  2020-06-01 00:11:46.5210
# 5626534          1168  2020-05-31 23:59:48.0660  2020-06-01 00:19:16.4730
#
#          start station id               start station name  \
# ...

# %%
combined_2020_df = pd.merge(combined_2020_df, df_2021_6, how="outer")
combined_2020_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                 592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                 702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...               ...                       ...                       ...
# 7508803           685  2020-06-30 23:59:41.1160  2020-07-01 00:11:06.7790
# 7508804           446  2020-06-30 23:59:46.4260  2020-07-01 00:07:13.0860
# 7508805           439  2020-06-30 23:59:47.4770  2020-07-01 00:07:06.5590
# 7508806           890  2020-06-30 23:59:53.3950  2020-07-01 00:14:43.4270
# 7508807           433  2020-06-30 23:59:53.9010  2020-07-01 00:07:07.0950
#
#          start station id               start station name  \
# ...

# %%
combined_2020_df = pd.merge(combined_2020_df, df_2021_7, how="outer")
combined_2020_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                 592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                 702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...               ...                       ...                       ...
# 9614611           877  2020-07-31 23:59:48.9250  2020-08-01 00:14:26.2540
# 9614612           839  2020-07-31 23:59:51.7740  2020-08-01 00:13:50.9750
# 9614613          1042  2020-07-31 23:59:56.1460  2020-08-01 00:17:18.5090
# 9614614           699  2020-07-31 23:59:57.4310  2020-08-01 00:11:36.5420
# 9614615           249  2020-07-31 23:59:58.7260  2020-08-01 00:04:08.2070
#
#          start station id               start station name  \
# ...

# %%
combined_2020_df = pd.merge(combined_2020_df, df_2021_8, how="outer")
combined_2020_df
# Out:
#           tripduration                 starttime                  stoptime  \
# 0                  789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                 1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                 1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                  592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                  702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...                ...                       ...                       ...
# 11944125          1562  2020-08-31 23:59:29.7690  2020-09-01 00:25:31.9660
# 11944126          1023  2020-08-31 23:59:32.1320  2020-09-01 00:16:35.3710
# 11944127           600  2020-08-31 23:59:33.0920  2020-09-01 00:09:33.4670
# 11944128           737  2020-08-31 23:59:35.7900  2020-09-01 00:11:53.2310
# 11944129           373  2020-08-31 23:59:45.3470  2020-09-01 00:05:59.1630
#
#           start station id               start station name  \
# ...

# %%
combined_2020_df = pd.merge(combined_2020_df, df_2021_9, how="outer")
combined_2020_df
# Out:
#           tripduration                 starttime                  stoptime  \
# 0                  789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                 1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                 1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                  592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                  702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...                ...                       ...                       ...
# 14432350          1818  2020-09-30 23:59:48.8460  2020-10-01 00:30:07.7810
# 14432351          1553  2020-09-30 23:59:53.7240  2020-10-01 00:25:47.1760
# 14432352           626  2020-09-30 23:59:54.6670  2020-10-01 00:10:21.6050
# 14432353           325  2020-09-30 23:59:56.2120  2020-10-01 00:05:21.3060
# 14432354           128  2020-09-30 23:59:57.8350  2020-10-01 00:02:06.0920
#
#           start station id               start station name  \
# ...

# %%
combined_2020_df = pd.merge(combined_2020_df, df_2021_10, how="outer")
combined_2020_df
# Out:
#           tripduration                 starttime                  stoptime  \
# 0                  789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                 1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                 1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                  592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                  702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...                ...                       ...                       ...
# 16681219          1120  2020-10-31 23:59:48.4470  2020-11-01 00:18:29.3280
# 16681220           859  2020-10-31 23:59:49.3770  2020-11-01 00:14:09.1920
# 16681221           546  2020-10-31 23:59:52.1040  2020-11-01 00:08:59.0710
# 16681222           748  2020-10-31 23:59:53.0290  2020-11-01 00:12:21.7830
# 16681223          1366  2020-10-31 23:59:57.9770  2020-11-01 00:22:44.1290
#
#           start station id                  start station name  \
# ...

# %%
combined_2020_df = pd.merge(combined_2020_df, df_2021_11, how="outer")
combined_2020_df
# Out:
#           tripduration                 starttime                  stoptime  \
# 0                  789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                 1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                 1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                  592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                  702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...                ...                       ...                       ...
# 18417923           257  2020-11-30 23:58:44.6840  2020-12-01 00:03:01.9470
# 18417924           617  2020-11-30 23:58:45.6210  2020-12-01 00:09:02.8300
# 18417925           116  2020-11-30 23:58:45.7200  2020-12-01 00:00:41.9570
# 18417926           409  2020-11-30 23:59:20.1480  2020-12-01 00:06:09.7540
# 18417927           301  2020-11-30 23:59:47.9750  2020-12-01 00:04:49.2260
#
#           start station id               start station name  \
# ...

# %%
combined_2020_df = pd.merge(combined_2020_df, df_2021_12, how="outer")
combined_2020_df
# Out:
#           tripduration                 starttime                  stoptime  \
# 0                  789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                 1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                 1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                  592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                  702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...                ...                       ...                       ...
# 19506852          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 19506853           288  2020-12-31 23:58:37.8400  2021-01-01 00:03:26.3250
# 19506854           152  2020-12-31 23:58:52.8090  2021-01-01 00:01:25.6720
# 19506855           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
# 19506856          2589  2020-12-31 23:59:57.4070  2021-01-01 00:43:06.4490
#
#           start station id                   start station name  \
# ...

# %%
station_2020_combined_df = combined_2020_df.groupby(["start station id"]).agg({'tripduration':"count"})
station_2020_combined_df["Total_trip_duration"] = combined_2020_df.groupby(["start station id"]).agg({'tripduration':"sum"})
station_2020_combined_df["average_trip_duration"] = combined_2020_df.groupby(["start station id"]).agg({'tripduration':"mean"})
station_2020_combined_df["latitude"] = combined_2020_df.groupby(["start station id"]).agg({'start station latitude':"mean"})
station_2020_combined_df["longitude"] = combined_2020_df.groupby(["start station id"]).agg({'start station longitude':"mean"})
station_2020_combined_df.head()
# Out:
#                   tripduration  Total_trip_duration  average_trip_duration  \
# start station id
# 72                       34550             47548965            1376.236324
# 79                       19560             25218725            1289.300869
# 82                       12009             13147793            1094.828295
# 83                       18797             28022697            1490.806884
# 116                      44608             46245054            1036.698664
#
#                    latitude  longitude
# start station id
# 72                40.767272 -73.993929
# 79                40.719116 -74.006667
# 82                40.711174 -74.000166
# 83                40.683826 -73.976323
# 116               40.741776 -74.001497

# %%
station_2020_combined_df.to_csv("collatedData/StartStationID.csv")

# %%
station_end = combined_2020_df.groupby(["end station id"]).agg({'tripduration':"count"})
station_end["Total_trip_duration"] = combined_2020_df.groupby(["end station id"]).agg({'tripduration':"sum"})
station_end["average_trip_duration"] = combined_2020_df.groupby(["end station id"]).agg({'tripduration':"mean"})
station_end["latitude"] = combined_2020_df.groupby(["end station id"]).agg({'end station latitude':"mean"})
station_end["longitude"] = combined_2020_df.groupby(["end station id"]).agg({'end station longitude':"mean"})
station_end.head()
# Out:
#                 tripduration  Total_trip_duration  average_trip_duration  \
# end station id
# 72                     34532             48778218            1412.551199
# 79                     19981             25747489            1288.598619
# 82                     12170             18485345            1518.927280
# 83                     19257             30368746            1577.023732
# 116                    44770             40148951             896.782466
#
#                  latitude  longitude
# end station id
# 72              40.767272 -73.993929
# 79              40.719116 -74.006667
# 82              40.711174 -74.000166
# 83              40.683826 -73.976323
# 116             40.741776 -74.001497

# %%
station_end.to_csv("collatedData/EndStationID.csv")
